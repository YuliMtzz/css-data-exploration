# %%
#Carga de librerias
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# carga de base de datos 
bookings = pd.read_csv("bookings_report_casas_sabro - Sheet1.csv")
bookings.head()
# Out:
#                        Listing Name Check-in Date Check-out Date  Booked Date  \
# 0   OASIS PH - Hot Tub | 2 Terraces   25 abr 2026    09 may 2026  07 abr 2026
# 1   OASIS PH - Hot Tub | 2 Terraces   16 may 2026    16 jun 2026  19 mar 2026
# 2  OASIS 201 - Balcony | Tub | 500M   15 mar 2026    19 abr 2026  06 mar 2026
# 3  OASIS 201 - Balcony | Tub | 500M   13 feb 2026    13 mar 2026  08 feb 2026
# 4   OASIS PH - Hot Tub | 2 Terraces   12 mar 2026    23 abr 2026  08 feb 2026
#
#   Average Daily Rate Rental Revenue Total Revenue Currency Booking Source  \
# 0           $ 103.39     $ 1,447.50    $ 1,497.50      USD         Airbnb
# 1            $ 77.81     $ 2,412.00    $ 2,462.00      USD         Airbnb
# 2            $ 41.66     $ 1,458.00    $ 1,483.00      USD         Airbnb
# 3            $ 40.93     $ 1,146.00    $ 1,171.00      USD         Airbnb
# 4            $ 79.52     $ 3,340.00    $ 3,390.00      USD         Airbnb
#
#   Booking Status  ...                            Listing ID  \
# 0         Booked  ...  f4eb04a3-fd3c-447f-8a01-31e260bbb89b
# 1         Booked  ...  f4eb04a3-fd3c-447f-8a01-31e260bbb89b
# 2         Booked  ...  9fa010e4-9b94-4b9b-b6de-1792596bb063
# 3         Booked  ...  9fa010e4-9b94-4b9b-b6de-1792596bb063
# 4         Booked  ...  f4eb04a3-fd3c-447f-8a01-31e260bbb89b
#
#                                 Unit ID         PMS Property Name BR Count  \
# 0  f4eb04a3-fd3c-447f-8a01-31e260bbb89b  Hospitable           NaN        2
# 1  f4eb04a3-fd3c-447f-8a01-31e260bbb89b  Hospitable           NaN        2
# 2  9fa010e4-9b94-4b9b-b6de-1792596bb063  Hospitable           NaN        1
# 3  9fa010e4-9b94-4b9b-b6de-1792596bb063  Hospitable           NaN        1
# 4  f4eb04a3-fd3c-447f-8a01-31e260bbb89b  Hospitable           NaN        2
#
#   Group  Sub-Group  Tags      City  Sync Price
# 0   NaN        NaN   NaN  Medellín          On
# 1   NaN        NaN   NaN  Medellín          On
# 2   NaN        NaN   NaN  Medellín          On
# 3   NaN        NaN   NaN  Medellín          On
# 4   NaN        NaN   NaN  Medellín          On
#
# [5 rows x 23 columns]

# %%
#Limpieza y preparación de datos
bookings.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Listing Name           248 non-null    str
#  1   Check-in Date          248 non-null    str
#  2   Check-out Date         248 non-null    str
#  3   Booked Date            248 non-null    str
#  4   Average Daily Rate     248 non-null    str
#  5   Rental Revenue         248 non-null    str
#  6   Total Revenue          248 non-null    str
#  7   Currency               248 non-null    str
#  8   Booking Source         248 non-null    str
#  9   Booking Status         248 non-null    str
#  10  Length of Stay (Days)  248 non-null    int64
#  11  Booking Window (Days)  248 non-null    int64
#  12  Reservation ID         248 non-null    str
#  13  Listing ID             248 non-null    str
#  14  Unit ID                248 non-null    str
#  15  PMS                    248 non-null    str
#  16  Property Name          0 non-null      float64
#  17  BR Count               248 non-null    int64
#  18  Group                  0 non-null      float64
#  19  Sub-Group              0 non-null      float64
#  20  Tags                   0 non-null      float64
#  21  City                   248 non-null    str
#  22  Sync Price             248 non-null    str
# dtypes: float64(4), int64(3), str(16)
# memory usage: 44.7 KB
